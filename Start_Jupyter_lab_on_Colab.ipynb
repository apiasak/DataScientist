# %% [markdown]
# <a href="https://colab.research.google.com/github/apiasak/DataScientist/blob/master/Start_Jupyter_lab_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![118766002_1056224604795716_8758614675155448954_n.jpg](data:image/jpeg;base64,...)

# %%
# !pip install kora -q

# %%
from kora import jupyter

# %%
jupyter.start(lab=True)
# Out:
# https://0569e70f9735.ngrok.io

# %%
jupyter.stop()
